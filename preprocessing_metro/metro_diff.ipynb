# %%
import pandas as pd

import matplotlib.pyplot as plt
plt.rc('font',family='AppleGothic')

# %%
df=pd.read_csv('../raw_data/seoul_metro_raw/merged_raw_metro.csv',index_col=0)

# %%
df.set_index('날짜',inplace=True)

# %%
df.index = pd.to_datetime(df.index,format='%Y-%m-%d')

# %%
df_raw = df.copy()

# %%
temp=df[df['구분']=='하차']

# %%
temp.drop('구분',axis=1,inplace=True)
# Out:
# /var/folders/r1/58cpj4hx7j75vx_3j1y6vpvw0000gn/T/ipykernel_3044/2268280650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.drop('구분',axis=1,inplace=True)

# %%
from itertools import cycle, islice
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, 10))

# %%
a['before_noon'].sort_values(ascending=False).head(10)
# Out:
# 역명
# 동작(현충원)        17.172708
# 부천종합운동장        10.102910
# 삼산체육관          10.084802
# 학여울             9.637658
# 당고개             8.352677
# 월드컵경기장(성산)      7.790316
# 올림픽공원(한국체대)     7.561770
# 종합운동장           7.453879
# 구파발             7.117574
# 방화              5.234716
# Name: before_noon, dtype: float64

# %%
temp_2017=temp[temp.index.year == 2017]

before_noon=['05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12']
after_noon = ['12~13', '13~14', '14~15', '15~16', '16~17']
dinner =['17~18', '18~19', '19~20','20~21', '21~22', '22~23', '23~24', '00~01']

temp.loc[:,before_noon].sum(axis=1)

merged_temp = temp.copy()
merged_temp=pd.DataFrame(merged_temp.iloc[:,0])

merged_temp['before_noon'] = temp.loc[:,before_noon].sum(axis=1)
merged_temp['after_noon'] = temp.loc[:,after_noon].sum(axis=1)
merged_temp['dinner'] = temp.loc[:,dinner].sum(axis=1)
merged_temp['total'] = merged_temp.iloc[:,1:].sum(axis=1)

tmp=merged_temp[merged_temp.index.year == 2017]

a=(tmp.groupby('역명').max()-tmp.groupby('역명').mean()) / tmp.groupby('역명').std()
a.sort_values('total',ascending=False)
plt.figure(figsize=(14,7))

plt.subplot(2,2,1)
a['before_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('before_noon',fontsize=15)
plt.subplot(2,2,2)
a['after_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('after_noon',fontsize=15)
plt.subplot(2,2,3)
a['dinner'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('dinner',fontsize=15)
plt.subplot(2,2,4)
a['total'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.title('total',fontsize=15)
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()

# %%
temp_2017=temp[temp.index.year == 2018]

before_noon=['05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12']
after_noon = ['12~13', '13~14', '14~15', '15~16', '16~17']
dinner =['17~18', '18~19', '19~20','20~21', '21~22', '22~23', '23~24', '00~01']

temp.loc[:,before_noon].sum(axis=1)

merged_temp = temp.copy()
merged_temp=pd.DataFrame(merged_temp.iloc[:,0])

merged_temp['before_noon'] = temp.loc[:,before_noon].sum(axis=1)
merged_temp['after_noon'] = temp.loc[:,after_noon].sum(axis=1)
merged_temp['dinner'] = temp.loc[:,dinner].sum(axis=1)
merged_temp['total'] = merged_temp.iloc[:,1:].sum(axis=1)

tmp=merged_temp[merged_temp.index.year == 2018]

a=(tmp.groupby('역명').max()-tmp.groupby('역명').mean()) / tmp.groupby('역명').std()
a.sort_values('total',ascending=False)

plt.figure(figsize=(14,7))

plt.subplot(2,2,1)
a['before_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('before_noon',fontsize=15)
plt.subplot(2,2,2)
a['after_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('after_noon',fontsize=15)
plt.subplot(2,2,3)
a['dinner'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('dinner',fontsize=15)
plt.subplot(2,2,4)
a['total'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.title('total',fontsize=15)
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()

# %%
temp_2017=temp[temp.index.year == 2019]

before_noon=['05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12']
after_noon = ['12~13', '13~14', '14~15', '15~16', '16~17']
dinner =['17~18', '18~19', '19~20','20~21', '21~22', '22~23', '23~24', '00~01']

temp.loc[:,before_noon].sum(axis=1)

merged_temp = temp.copy()
merged_temp=pd.DataFrame(merged_temp.iloc[:,0])

merged_temp['before_noon'] = temp.loc[:,before_noon].sum(axis=1)
merged_temp['after_noon'] = temp.loc[:,after_noon].sum(axis=1)
merged_temp['dinner'] = temp.loc[:,dinner].sum(axis=1)
merged_temp['total'] = merged_temp.iloc[:,1:].sum(axis=1)

tmp=merged_temp[merged_temp.index.year == 2019]

a=(tmp.groupby('역명').max()-tmp.groupby('역명').mean()) / tmp.groupby('역명').std()
a.sort_values('total',ascending=False)

plt.figure(figsize=(14,7))

plt.subplot(2,2,1)
a['before_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('before_noon',fontsize=15)
plt.subplot(2,2,2)
a['after_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('after_noon',fontsize=15)
plt.subplot(2,2,3)
a['dinner'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('dinner',fontsize=15)
plt.subplot(2,2,4)
a['total'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.title('total',fontsize=15)
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()

# %%
temp_2017=temp[temp.index.year == 2020]

before_noon=['05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12']
after_noon = ['12~13', '13~14', '14~15', '15~16', '16~17']
dinner =['17~18', '18~19', '19~20','20~21', '21~22', '22~23', '23~24', '00~01']

temp.loc[:,before_noon].sum(axis=1)

merged_temp = temp.copy()
merged_temp=pd.DataFrame(merged_temp.iloc[:,0])

merged_temp['before_noon'] = temp.loc[:,before_noon].sum(axis=1)
merged_temp['after_noon'] = temp.loc[:,after_noon].sum(axis=1)
merged_temp['dinner'] = temp.loc[:,dinner].sum(axis=1)
merged_temp['total'] = merged_temp.iloc[:,1:].sum(axis=1)

tmp=merged_temp[merged_temp.index.year == 2020]

a=(tmp.groupby('역명').max()-tmp.groupby('역명').mean()) / tmp.groupby('역명').std()
a.sort_values('total',ascending=False)

plt.figure(figsize=(14,7))

plt.subplot(2,2,1)
a['before_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('before_noon',fontsize=15)
plt.subplot(2,2,2)
a['after_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('after_noon',fontsize=15)
plt.subplot(2,2,3)
a['dinner'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('dinner',fontsize=15)
plt.subplot(2,2,4)
a['total'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.title('total',fontsize=15)
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()

# %%
temp_2017=temp[temp.index.year == 2021]

before_noon=['05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12']
after_noon = ['12~13', '13~14', '14~15', '15~16', '16~17']
dinner =['17~18', '18~19', '19~20','20~21', '21~22', '22~23', '23~24', '00~01']

temp.loc[:,before_noon].sum(axis=1)

merged_temp = temp.copy()
merged_temp=pd.DataFrame(merged_temp.iloc[:,0])

merged_temp['before_noon'] = temp.loc[:,before_noon].sum(axis=1)
merged_temp['after_noon'] = temp.loc[:,after_noon].sum(axis=1)
merged_temp['dinner'] = temp.loc[:,dinner].sum(axis=1)
merged_temp['total'] = merged_temp.iloc[:,1:].sum(axis=1)

tmp=merged_temp[merged_temp.index.year == 2021]

a=(tmp.groupby('역명').max()-tmp.groupby('역명').mean()) / tmp.groupby('역명').std()
a.sort_values('total',ascending=False)

plt.figure(figsize=(14,7))

plt.subplot(2,2,1)
a['before_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('before_noon',fontsize=15)
plt.subplot(2,2,2)
a['after_noon'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('after_noon',fontsize=15)
plt.subplot(2,2,3)
a['dinner'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.xticks(rotation=25)
plt.title('dinner',fontsize=15)
plt.subplot(2,2,4)
a['total'].sort_values(ascending=False).head(10).plot(kind='bar',color=my_colors)
plt.title('total',fontsize=15)
plt.xticks(rotation=25)
plt.tight_layout()
plt.show()
